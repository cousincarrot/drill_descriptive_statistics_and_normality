# %% [markdown]
#  1.Generate a random variable with 100 datapoints using the code distributionvar = np.random.distributionname([arguments], 100), replacing distributionvar with an appropriate variable name and distributionname with the name of the distribution you’ve chosen, and filling in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, go back to the “Other Distributions” assignment for examples of code to use as a starting point.
#
# 2.Graph the variable using a histogram.
#
# 3.Compute the mean and standard deviation and plot them as vertical lines on the histogram. (Hint: the “When Does It Break?” assignment you just completed can help you here.)
#
# 4.Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics of the distributions that could be usefully described using the mean and/or standard deviation, versus the ones that could not?
#
# Additionally:
#
# Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and standard deviation of 1.
# Add them together to create a third variable.
# Graph the third variable using a histogram.
# Compute the mean and standard deviation and plot them as vertical lines on the histogram.
# Evaluate the descriptive statistics against the data.

# %%
import pandas as pd
from collections import Counter
import numpy as np
import statistics
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1
#Generate a Poisson distribution with lambda = 3
poisson = np.random.poisson(3, 100)

poisson_mean = np.mean(poisson)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
poisson_std = np.std(poisson, axis=None, dtype=float, out=None, ddof=1)

#p = avg_time.plot(figsize=15,5),legend=False,kind="bar",rot=45,color="blue",fontsize=16,yerr=std)
#one suggestion for plotting mean and std deviation

# Plot a histogram.
plt.hist(poisson)

#add vertical lines to represent the mean and std deviation.
plt.axvline(poisson_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(poisson_mean + poisson_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(poisson_mean - poisson_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

# Print the histogram.
plt.show()

# %%
#2
expo = np.random.exponential(scale=1.0, size=100)

expo_mean = np.mean(expo)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
expo_std = np.std(expo, axis=None, dtype=float, out=None, ddof=1)

plt.hist(expo)

#add vertical lines to represent the mean and std deviation.
plt.axvline(expo_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(expo_mean + expo_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(expo_mean - expo_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()

# %%
#3
uni = np.random.uniform(low=0.0, high=1.0, size=100)

uni_mean = np.mean(uni)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
uni_std = np.std(uni, axis=None, dtype=float, out=None, ddof=1)

plt.hist(uni)

#add vertical lines to represent the mean and std deviation.
plt.axvline(uni_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(uni_mean + uni_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(uni_mean - uni_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()

# %%
#4
pwr = np.random.power(1, size=100)

pwr_mean = np.mean(pwr)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
pwr_std = np.std(pwr, axis=None, dtype=float, out=None, ddof=1)

plt.hist(pwr)

#add vertical lines to represent the mean and std deviation.
plt.axvline(pwr_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(pwr_mean + pwr_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(pwr_mean - pwr_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()

# %%
#5
#tri = np.random.triangular(left, mode, right, size=None)
tri = np.random.triangular(0, 20, 100, size=100)

tri_mean = np.mean(tri)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
tri_std = np.std(tri, axis=None, dtype=float, out=None, ddof=1)

plt.hist(tri)

#add vertical lines to represent the mean and std deviation. Not sure about first argument in these lines.
plt.axvline(tri_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(tri_mean + tri_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(tri_mean - tri_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()

# %%
#6
#np.random.pareto(a, size=None)
pareto = np.random.pareto(1000, size=100)

pareto_mean = np.mean(pareto)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
pareto_std = np.std(pareto, axis=None, dtype=float, out=None, ddof=1)

plt.hist(pareto)

#add vertical lines to represent the mean and std deviation. Not sure about first argument in these lines.
plt.axvline(pareto_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(pareto_mean + pareto_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(pareto_mean - pareto_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()

# %%
#Additionally
#df = pd.DataFrame({'rand': np.random.normal(mean, sd, 1000)})

norm1 = pd.DataFrame({'rand': np.random.normal(5, 0.5, 100)})
norm2 = pd.DataFrame({'rand': np.random.normal(10, 1, 100)})

#add these two together...

new_norm = np.concatenate((norm1, norm2), axis=0)

#then plot it and ssee the new mean and std deviation

new_norm_mean = np.mean(new_norm)

# numpy.std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=<class 'numpy._globals._NoValue'>)
new_norm_std = np.std(new_norm, axis=None, dtype=float, out=None, ddof=1)

plt.hist(new_norm)

#add vertical lines to represent the mean and std deviation. Not sure about first argument in these lines.
plt.axvline(new_norm_mean, color='#333333', linestyle='solid', linewidth=1, alpha=0.75)
plt.axvline(new_norm_mean + new_norm_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)
plt.axvline(new_norm_mean - new_norm_std, color='#666666', linestyle='dashed', linewidth=1, alpha=0.75)

plt.show()
